# %% [markdown]
# <a href="https://colab.research.google.com/github/samruddhisomnathe/Prediect-Salary-Using-Linear-Regression/blob/main/salary_processing_using_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')
df.head

# %%
df.duplicated()

# %%
df.describe()

# %%
df.mean()

# %%
df.median()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/ybifoundation/Dataset/main/Salary%20Data.csv')
x = df[['Experience Years']]
y = df['Salary']

plt.scatter(x, y)
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.show()

# %%
df.shape

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.7,random_state=2529)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape

# %%
lr=LinearRegression()

# %%
lr=LinearRegression()
lr.fit(x_train , y_train)

# %%
lr.score(x_test,y_test)*100

# %%
Year=int(input("Enter your Experience in year:"))
salary=lr.predict([[Year]])
print("Your salary is:",salary)

# %%
x = df[['Experience Years']]
y = df['Salary']

# %%
plt.scatter(x, y)
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.show()
